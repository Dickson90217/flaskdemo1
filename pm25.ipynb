# %%
import pandas as pd

# %%
url='https://data.epa.gov.tw/api/v1/aqx_p_02?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&sort=ImportDate%20desc&format=csv'

# %%
df=pd.read_csv(url).dropna()
df
# Out:
#     Site county  PM25  DataCreationDate ItemUnit
# 0     前鎮    高雄市    37  2022-01-05 18:00    μg/m3
# 1     汐止    新北市    34  2022-01-05 18:00    μg/m3
# 2     萬里    新北市    12  2022-01-05 18:00    μg/m3
# 3     新店    新北市    15  2022-01-05 18:00    μg/m3
# 4     土城    新北市    25  2022-01-05 18:00    μg/m3
# ..   ...    ...   ...               ...      ...
# 102   宜蘭    宜蘭縣    19  2022-01-05 18:00    μg/m3
# 103   中壢    桃園市    29  2022-01-05 18:00    μg/m3
# 104   竹山    南投縣    39  2022-01-05 18:00    μg/m3
# 105   復興    高雄市    40  2022-01-05 18:00    μg/m3
# 106   頭份    苗栗縣    24  2022-01-05 18:00    μg/m3
#
# [107 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SiteId         78 non-null     int64
#  1   SiteName       78 non-null     object
#  2   County         78 non-null     object
#  3   ItemId         78 non-null     int64
#  4   ItemName       78 non-null     object
#  5   ItemEngName    78 non-null     object
#  6   ItemUnit       78 non-null     object
#  7   MonitorDate    78 non-null     object
#  8   Concentration  78 non-null     int64
# dtypes: int64(3), object(6)
# memory usage: 5.6+ KB

# %%
columns=['county','Site','PM25']
values=df[columns].values.tolist()

columns,values
# Out:
# (['county', 'Site', 'PM25'],
#  [['高雄市', '前鎮', 37],
#   ['新北市', '汐止', 34],
#   ['新北市', '萬里', 12],
#   ['新北市', '新店', 15],
#   ['新北市', '土城', 25],
#   ['新北市', '新莊', 20],
#   ['新北市', '林口', 21],
#   ['新北市', '淡水', 10],
#   ['臺北市', '古亭', 22],
#   ['臺北市', '大同', 19],
#   ['桃園市', '桃園', 34],
#   ['臺中市', '大里', 31],
#   ['臺中市', '忠明', 30],
#   ['高雄市', '美濃', 44],
#   ['苗栗縣', '三義', 29],
#   ['臺中市', '沙鹿', 29],
#   ['臺中市', '西屯', 27],
#   ['彰化縣', '彰化', 25],
#   ['彰化縣', '二林', 25],
#   ['南投縣', '南投', 33],
#   ['雲林縣', '斗六', 41],
#   ['高雄市', '前金', 36],
#   ['雲林縣', '臺西', 16],
#   ['臺南市', '安南', 38],
#   ['臺南市', '臺南', 49],
#   ['高雄市', '仁武', 51],
#   ['高雄市', '鳳山', 46],
#   ['高雄市', '大寮', 42],
#   ['新北市', '三重', 30],
#   ['臺北市', '中山', 21],
#   ['高雄市', '左營', 42],
#   ['雲林縣', '麥寮', 21],
#   ['桃園市', '大園', 17],
#   ['桃園市', '觀音', 21],
#   ['屏東縣', '屏東', 26],
#   ['屏東縣', '潮州', 13],
#   ['屏東縣', '恆春', 3],
#   ['臺東縣', '臺東', 5],
#   ['花蓮縣', '花蓮', 6],
#   ['桃園市', '龍潭', 32],
#   ['新竹縣', '湖口', 32],
#   ['宜蘭縣', '冬山', 17],
#   ['臺中市', '豐原', 22],
#   ['嘉義縣', '朴子', 33],
#   ['臺南市', '新營', 29],
#   ['新北市', '永和', 27],
#   ['高雄市', '橋頭', 61],
#   ['南投縣', '埔里', 22],
#   ['高雄市', '林園', 13],
#   ['金門縣', '金門', 31],
#   ['澎湖縣', '馬公', 12],
#   ['臺東縣', '關山', 6],
#   ['基隆市', '基隆', 15],
#   ['新竹縣', '竹東', 38],
#   ['雲林縣', '崙背', 23],
#   ['高雄市', '小港', 38],
#   ['嘉義縣', '新港', 27],
#   ['苗栗縣', '三義', 29],
#   ['臺中市', '沙鹿', 29],
#   ['臺中市', '西屯', 27],
#   ['彰化縣', '彰化', 25],
#   ['彰化縣', '二林', 25],
#   ['南投縣', '南投', 33],
#   ['雲林縣', '斗六', 41],
#   ['雲林縣', '崙背', 23],
#   ['雲林縣', '臺西', 16],
#   ['臺南市', '安南', 38],
#   ['臺南市', '臺南', 49],
#   ['高雄市', '仁武', 51],
#   ['宜蘭縣', '冬山', 17],
#   ['金門縣', '金門', 31],
#   ['澎湖縣', '馬公', 12],
#   ['臺東縣', '關山', 6],
#   ['高雄市', '大寮', 42],
#   ['高雄市', '左營', 42],
#   ['屏東縣', '屏東', 26],
#   ['屏東縣', '潮州', 13],
#   ['臺東縣', '臺東', 5],
#   ['花蓮縣', '花蓮', 6],
#   ['宜蘭縣', '冬山', 17],
#   ['新北市', '永和', 27],
#   ['南投縣', '埔里', 22],
#   ['金門縣', '金門', 31],
#   ['臺東縣', '關山', 6],
#   ['澎湖縣', '馬公', 12],
#   ['臺東縣', '關山', 6],
#   ['新北市', '板橋', 19],
#   ['臺北市', '萬華', 20],
#   ['臺北市', '陽明', 4],
#   ['連江縣', '馬祖', 21],
#   ['彰化縣', '大城', 20],
#   ['嘉義市', '嘉義', 41],
#   ['新北市', '富貴角', 10],
#   ['新北市', '菜寮', 20],
#   ['臺北市', '士林', 16],
#   ['臺南市', '善化', 47],
#   ['臺北市', '松山', 21],
#   ['桃園市', '平鎮', 27],
#   ['新竹市', '新竹', 23],
#   ['苗栗縣', '苗栗', 27],
#   ['彰化縣', '線西', 34],
#   ['高雄市', '楠梓', 52],
#   ['宜蘭縣', '宜蘭', 19],
#   ['桃園市', '中壢', 29],
#   ['南投縣', '竹山', 39],
#   ['高雄市', '復興', 40],
#   ['苗栗縣', '頭份', 24]])
